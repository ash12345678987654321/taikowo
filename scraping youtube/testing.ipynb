# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

import urllib.parse as p
import re
import os
import pickle

SCOPES = ["https://www.googleapis.com/auth/youtube.force-ssl"]

# %%
def youtube_authenticate():
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
    api_service_name = "youtube"
    api_version = "v3"
    client_secrets_file = "credentials.json"
    creds = None
    # the file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)
    # if there are no (valid) credentials availablle, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        # save the credentials for the next run
        with open("token.pickle", "wb") as token:
            pickle.dump(creds, token)

    return build(api_service_name, api_version, credentials=creds)

# %%
youtube = youtube_authenticate()

# %%
def get_video_id_by_url(url):
    """
    Return the Video ID from the video `url`
    """
    # split URL parts
    parsed_url = p.urlparse(url)
    # get the video ID by parsing the query of the URL
    video_id = p.parse_qs(parsed_url.query).get("v")
    if video_id:
        return video_id[0]
    else:
        raise Exception(f"Wasn't able to parse video URL: {url}")

# %%
def get_video_details(youtube, **kwargs):
    return youtube.videos().list(
        part="snippet,contentDetails,statistics",
        **kwargs
    ).execute()

# %%
def get_video_metadata(url):
    dat=get_video_details(youtube,id=get_video_id_by_url(url))["items"][0]
    
    res={}
    res["views"]=dat["statistics"]["viewCount"]
    res["likes"]=dat["statistics"]["likeCount"]
    res["dislikes"]=dat["statistics"]["dislikeCount"]
    res["comments"]=dat["statistics"]["commentCount"]
    
    res["title"]=dat["snippet"]["title"]
    res["desc"]=dat["snippet"]["description"]
    res["thumbnail"]=dat["snippet"]["thumbnails"]["maxres"]["url"]
    
    return res

# %%
get_video_metadata("https://www.youtube.com/watch?v=951X1IgtL5M")
# Out:
# {'views': '790806',
#  'likes': '59614',
#  'dislikes': '308',
#  'comments': '1658',
#  'title': 'How Skrillex makes his basslines',
#  'desc': 'with a Tibetan monk in his computer..',
#  'thumbnail': 'https://i.ytimg.com/vi/951X1IgtL5M/maxresdefault.jpg'}

# %%
def get_channel_videos(youtube, **kwargs):
    return youtube.search().list(
        **kwargs
    ).execute()

# %%
def crawl_channel(channelId):
    ids=[]
    nxt=None
    
    while(True):
        res=get_channel_videos(youtube,part="snippet",channelId=channelId,type="video",pageToken=nxt)
        videos=res.get("items")
        
        for video in videos:
            ids.append(video["id"]["videoId"])
            
        if "nextPageToken" in res:
            nxt=res["nextPageToken"]
        else:
            break
    
    return ids

# %%
crawl_channel("UCRWOdwLRsenx2jLaiCAIU4A")
# Out:
# ['kmte4HGJCdo',
#  'T71vkqZeniU',
#  'R4zha-fcxH8',
#  'E4kRDlsMLNM',
#  'ABp2hdvgkxk',
#  'KhUYTvpNDNI',
#  'zTpu9bQmBlQ',
#  'b-WtGGawa7M',
#  '4xLWjHNrIys',
#  'xbxP-s_-arc',
#  'AtLU2bHiVbE',
#  'GwnGVNuuYWw',
#  'YTyx9bXmMIw',
#  'pKE7iMKJGHg',
#  'SxBrZ6tpgOQ',
#  '54cchVisr2A',
#  'KgRZ5ohwLKc',
#  '_Lcstg3DVfg',
#  'imkKlp3YadY',
#  '5i_oD45sAWE',
#  'tULklvbdi5w',
#  'uDyNjSQVL6M',
#  'a1ENF43IIeI',
#  'TlMg3plBhiU',
#  '39_AInFOrm8',
#  '84d9ooGeH48',
#  '4t_hUQNkwVU',
#  'TwX8tiuowU0',
#  'M3qjF2vGcA8',
#  'X13cOgv1fxQ',
#  'X13cOgv1fxQ',
#  'YTmvCBftDXk',
#  'ANwXRqBq5ik',
#  'CLaiky2Cy4k',
#  'gGxyb_WlFmM',
#  'e_NT_9fr7uE',
#  '9FYyxXpI9CM',
#  'qt0InK2pofo',
#  'J_f-Jc8sMw8',
#  'lVE_CLfBwxY',
#  'qopkBKmmGkE',
#  'E9L7z5xu7Q4',
#  'lXqVu6soRCQ',
#  'WARGstLj150',
#  'hNbQB2pHYnk',
#  'OnsIBD8h91A',
#  '5aAUbn7W6sg',
#  'EF2DlcV0dUg',
#  'fW6Kz4C6-TA',
#  'vL2F55kMbyA',
#  'XQfTgvhQeLw',
#  'VndkM923RM8',
#  'pYZ4AKs8XtQ',
#  'uwhfH_ajsiE',
#  'XoNlPHsUfTA',
#  'GxFwNLfpdDQ',
#  'f4MdGGPHu6w',
#  '-080QH5__LM',
#  '-Y87rT2z5XE',
#  '9GzM-WXNEEc',
#  'WHSNkzZtQdQ',
#  'rylXYMJLs7A',
#  'sqCz3s-eqtU',
#  'eOC0sIfoUuE',
#  '8N6zjqyEUwI',
#  'Il47c3PfFRA',
#  'D0EIBi3QAnw']

# %%
crawl_channel("UCHnyfMqiRRG1u-2MsSQLbXA") #veritasium
# Out:
# ['1TKSfAkWWN0',
#  'g_IaVepNDT4',
#  'IcrBqCFLHIY',
#  '2OSrvzNW9FE',
#  'vVKFBaaL4uM',
#  'iphcyNWFD10',
#  'yArprk0q9eE',
#  'zUyH3XhpLTo',
#  'vqDbMEdLiCs',
#  'a8FTr2qMutA',
#  'txmKr69jGBk',
#  'c6wuh0NRG1s',
#  'Ztc6QPNUqls',
#  'tLMpdBjA2SU',
#  'XBr4GkRnY04',
#  'ty9QSiVC2g0',
#  'y9c8oZ49pFc',
#  'BD6h-wDj7bw',
#  'fu3645D4ZlI',
#  'PifL8bAybyc',
#  'WIyTZDHuarQ',
#  'vBX-KulgJ1o',
#  'gM3zP72-rJE',
#  'eCMmmEEyOO0',
#  'zNzzGgr2mhk',
#  'J3xLuZNKhlY',
#  'ph8xusY3GTM',
#  'BickMFHAZR0',
#  'sehKAccM8p0',
#  '1tSqSMOyNFE',
#  'cY_o4A1wzsg',
#  'J3xLuZNKhlY',
#  'ph8xusY3GTM',
#  'BickMFHAZR0',
#  'sehKAccM8p0',
#  '1tSqSMOyNFE',
#  '2KZb2_vcNTg',
#  'rM04U5BO3Ug',
#  'aFO4PBolwFg',
#  'DWkYRh6OXy8',
#  'zUDqI9PJpc8',
#  'sMb00lz-IfE',
#  'I_rw-AJqpCM',
#  'TRL7o2kPqw0',
#  'YMPzDiraNnA',
#  'TcxZSmzPw8k',
#  'stRPiifxQnM',
#  'oKb2tCtpvNU',
#  '72DCj3BztG4',
#  '23f1jvGUWJs',
#  'K4vyRvMASPU',
#  'g20JZ2HNZaw',
#  'EAyk2OsKvtU',
#  'cebFWOlx848',
#  'x4I9mmd-2Rc',
#  'LKPwKFigF8U',
#  'Yl_K2Ata6XY',
#  'Bz9D6xba9Og',
#  '-OqrZG-EBaQ',
#  'jIMihpDmBpY',
#  'j5v8D-alAKE',
#  'aIx2N-viNwY',
#  'lL2e0rWvjKI',
#  '_k9egfWvb7Y',
#  '3LopI4YeC4I',
#  'iQOHRKKNNLQ',
#  'X_tYrnv_o6A',
#  '7rAiZR_zasg',
#  'hNGJ0WHXMyE',
#  'ADJKsLEAOHo',
#  'mXaad0rsV38',
#  't-3jnOIJg4k',
#  '8bTdMmNZm2M',
#  'XRr1kaXKBsU',
#  'X-QFAB0gEtE',
#  'EPsG8td7C5k',
#  'ihv4f7VMeJw',
#  'HD3k1hgbUXQ',
#  '3LyFap2aUN0',
#  '649iUqrOKuE',
#  '5RLQ9WMP2Es',
#  'gMlf1ELvRzc',
#  'Oo0jm1PPRuo',
#  'ZQ--scjcAZ4',
#  'tDr26U49_VA',
#  'Y2nQ8isf55s',
#  'BtCNBh0AsWM',
#  'Stx6kLd9dYI',
#  'EKR-HydGohQ',
#  'ljoeOLuX6Z4',
#  '6YOz9Pxnzho',
#  'GzbKb59my3U',
#  '9DrBQg_n2Uo',
#  'IJ6GfBOYeLc',
#  'YJbKieEC49M',
#  'R13BD8qKeTg',
#  'GEmuEWjHr5c',
#  'aRhkQTQxm4w',
#  'SQggDnScsvI',
#  'xdJwG_9kF8s',
#  'BLYoyLcdGPc',
#  'Kp_kqamkYpw',
#  'vKA4w2O61Xo',
#  'KzOkuGQC3Rw',
#  'GeyDf4ooPdo',
#  'qQCVnjGUv24',
#  '4tgOyU34D44',
#  '42QuXLucH3Q',
#  'Iuv6hY6zsd0',
#  'pCON4zfMzjU',
#  '7pSqk-XV2QM',
#  'S1tFT4smd6E',
#  'M2CMH57hXmY',
#  'UBVV8pch1dM',
#  'fDek6cYijxI',
#  'NVKO7UCIlgs',
#  'd57C2drB_wc',
#  '2xKZRpAsWL8',
#  'N8HrMZB6_dU',
#  'uiyMuHuCFo4',
#  'vWVZ6APXM4w',
#  'SeDaOigLBTU',
#  'hbXDLKFkjm0',
#  'aJc4DEkSq4I',
#  '2_OEsf-1qgY',
#  'u3FB2SuKFfI',
#  'ovJcsL7vyrk',
#  '_dDqFB-PjWg',
#  'tYmMtSWPQEI',
#  'aKwJayXTZUs',
#  'Ux33-5k8cjg',
#  'mUxt--mMjwA',
#  'rAYW9n8i-C4',
#  'U2g1H5wPmUE',
#  'SmSJXC6_qQ8',
#  'rjDX5ItsOnQ',
#  'K-Fc08X56R0',
#  'c_e1wITe_ig',
#  'CNQf9vZqv7k',
#  'Cf7Ar3nEUmw',
#  '6wr_Zw1uGY8',
#  'lotbZQ55SgU',
#  'zuMjnP1YbPw',
#  'F69uqDIhr60',
#  '4qe1Ueifekg',
#  'rjht4oAByCI',
#  'S_GVbuddri8',
#  'YMDJA4UvXLA',
#  '97t7Xj_iBv0',
#  'm85qDk849_o',
#  'XBtBdNHBNSI',
#  '1Xp_imnO6WE',
#  '-zShHRkwSoI',
#  'GhsZUZmJvaM',
#  'mAA613hqqZ0',
#  'He30D8M5fNc',
#  'QD3hbVG1yxM',
#  '5NhIRwCq428',
#  'TQxeutcYP6I',
#  '48sCx-wBs34',
#  'wQmnztyXwVA',
#  'WwmJ5nMmigQ',
#  '5zI9sG3pjVU',
#  'Rwa26CXG1fc',
#  'pTn6Ewhb27k',
#  'liqF6EamiE4',
#  'LgrXd0NM2y8',
#  '058hRtaCWC0',
#  'HUmZrtiXDik',
#  'cO57Zm-WNmg',
#  'ZMByI4s-D-Y',
#  'AeJ9q45PfD0',
#  'Pm9CQn07OjU',
#  'dg3pza4y2ws',
#  'OWXoRSIxyIU',
#  '5yFnO2O6XPM',
#  'XAgXwUwQoPA',
#  'V9K6gjR07Po',
#  '_mCC-68LyZM',
#  '1VPfZ_XzisU',
#  'G10m2ZZRH4U',
#  '9DWnjcSo9J0',
#  'HgCXdNhVC1Q',
#  'QRt7LjqJ45k',
#  'p3b9pK-O6cE',
#  'Hx9TwM4Pmhc',
#  'qiiFMRYUEQM',
#  'SAQ-iIJkLzA',
#  'jn5M48MVWyg',
#  'kvARvzMErnk',
#  'knDIENvBTgw',
#  'GcdB5bFwio4',
#  'K7pQsR8WFSo',
#  'dBap_Lp-0oc',
#  'PCxOEyyzmvQ',
#  'oBdalzRJR5g',
#  'JUJPyQtoB5E',
#  'b3TRUDKpoAs',
#  '9zso7ChaQXQ',
#  'mNHp8iyyIjo',
#  'cU2dZz18P0c',
#  'mezkHBPLZ4A',
#  'eVtCO84MDj8',
#  'YHBvOOX3RJQ',
#  'pe83T9hISoY',
#  '4Wrc4fHSCpw',
#  'mXVGIb3bzHI',
#  'BZbChKzedEk',
#  'xmYss_hNF4Q',
#  'bcstc1ozczQ',
#  'wQTVcaA3PQw',
#  'dMwr0VYuExE',
#  'oVfHeWTKjag',
#  'TIe2oerd25c',
#  '1ZcOusmB4Ls',
#  'SN1Q5ru2fI0',
#  'iZCRFRgSgas',
#  'C_covjcIcZ4',
#  'uxPdPpi5W4o',
#  'dCXkaQa53QQ',
#  'eUzB0L0mSCI',
#  'akIBlq5xAec',
#  'GmlMV7bA0TM',
#  'eNx9tvCrvv8',
#  '38gVZgE39K8',
#  'rmI_9Hty-Lw',
#  's7MTM4BKZ_E',
#  'ro2MmmdARrs',
#  '2awbKQ2DLRE',
#  'ThwuT3_AG6w',
#  'h0SZZTBQmEs',
#  '_xU3IRbCbyQ',
#  'JsytnJ_pSf8',
#  '-PWMQR59M68',
#  'wU5XkhUGzBs',
#  'e69XZJ9DEj0',
#  'wCrtk-pyP0I',
#  'DBjZz0iQrzI',
#  'DL_mJeb6O04',
#  'AY6Bg4GzCGs',
#  'CNodxp9Jy4A',
#  'qQhUxd82Rr0',
#  'AcLh-aSUdx0',
#  'fHsa9DqmId8',
#  'kTXTPe3wahc',
#  'WBjY3QGNdAw',
#  'oLyfBhi3xj4',
#  '-i0InwW0V9k',
#  'qnOoDE9rj6w',
#  'q3kSW633bsk',
#  '-vomqiURUgA',
#  'M4CQ4T_K8Hw',
#  'zN6kCa6xi9k',
#  'KCL8zqjXbME',
#  '5JGSqG8OLjE',
#  'RwTjsRt0Fzo',
#  '7LGi-Dlb8Vs',
#  '5O-wAYKBBSc',
#  'N7lXymxsdhw',
#  'u7KpH9_I2Dw',
#  'bKldI-XGHIw',
#  'knwiWm4DpvQ',
#  'S20-1_XqVPM',
#  'UxbeLdXnaGU',
#  'lYc7kHXW0xg',
#  'cY-kiddvAg0',
#  'E7uGvsT_nnM',
#  'UMnQWn1rkAA',
#  '1iIv1SuS164',
#  '0dqX3NjwaQs',
#  'FhmLBxyX8Dw',
#  '1tXPVTIisl0',
#  'WMXhk_SATTc',
#  'og1CzUmnSlE',
#  'ljvX-RMv_lw',
#  'sWu9CyDwuFs',
#  'E9WUaBGH7_I',
#  '8EGXqZRwbzw',
#  'vKsof8ax_Ns',
#  '357_DHp3Nys',
#  'Bwf3msm7rqM',
#  'Jeb3O87iXWI',
#  'Jip3BbZBpsM',
#  'T_gCnf9-qW0',
#  'myh94hpFmJY',
#  'oPerfpxYJ1U',
#  'Yf0BN0kq7OU',
#  'CRSDxGtcsxE',
#  'Grv1RJkdyqI',
#  'dvk2PQNcg8w',
#  'GATuMWAFBUA',
#  'wGIZKETKKdw',
#  'KI5CUGQET5I',
#  'EJrmR-RGjUM',
#  '2PP9lRSmmeo',
#  'lRbI_vPyOnc',
#  '5THOUSvpCKk',
#  'exG4aGlCmEE',
#  'm8IGMFr62-Q',
#  'wzH_8TZ6oGI',
#  '1erU-Cwcl2c',
#  'EyT3Yukdlu4']

# %%
crawl_channel("UCXZpQgX1897wYDLtvzmgyIA") #facts verse
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-23-ad45367bb0bc> in <module>
# ----> 1 crawl_channel("UCXZpQgX1897wYDLtvzmgyIA") #facts verse
#
# <ipython-input-9-243fe769d66f> in crawl_channel(channelId)
#       4
#       5     while(True):
# ----> 6         res=get_channel_videos(youtube,part="snippet",channelId=channelId,type="video",pageToken=nxt)
#       7         videos=res.get("items")
#       8
#
# <ipython-input-8-d7bf0cf79472> in get_channel_videos(youtube, **kwargs)
#       1 def get_channel_videos(youtube, **kwargs):
#       2     return youtube.search().list(
# ----> 3         **kwargs
#       4     ).execute()
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     918             callback(resp)
#     919         if resp.status >= 300:
# --> 920             raise HttpError(resp, content, uri=self.uri)
#     921         return self.postproc(resp, content)
#     922
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&channelId=UCXZpQgX1897wYDLtvzmgyIA&type=video&pageToken=CPQDEAA&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.">

# %% [markdown]
# References

# %% [markdown]
# https://www.thepythoncode.com/article/using-youtube-api-in-python
